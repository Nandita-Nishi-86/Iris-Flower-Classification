# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix


import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_data = pd.read_csv('IRIS.csv')

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_data.shape
# Out:
# (150, 6)

# %%
print('number of rows in the dataset: ',iris_data.shape[0])
print('number of columns in the dataset: ',iris_data.shape[1])
# Out:
# number of rows in the dataset:  150
# number of columns in the dataset:  6

# %%
iris_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_data.describe(include = 'O')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
iris_data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_data.SepalWidthCm.mean()
# Out:
# np.float64(3.0540000000000003)

# %%
plt.figure(figsize=(8, 4))
sns.set_style=("white")

#create a boxplot plot
sns.boxplot(data=iris_data, x='Species', y='SepalLengthCm' ,palette= ['blue','green','red'])

plt.title('SepalLengthCm')
plt.xlabel('species')
plt.ylabel('Sepal Length (cm)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18944\3804212897.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris_data, x='Species', y='SepalLengthCm' ,palette= ['blue','green','red'])

# %%
plt.figure(figsize=(8, 4))

sns.kdeplot(x='SepalLengthCm', data=iris_data, hue='Species', fill='True', palette= ['blue','green','red'])
plt.xlabel(	'SepalLengthCm')
plt.ylabel('Density')
plt.title('Density plot of 	SepalLengthCm')

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 4))
sns.set_style=("white")

#create a boxplot plot
sns.boxplot(data=iris_data, x='Species', y='SepalWidthCm' ,palette= ['blue','green','red'])

plt.title('SepalWidthCm')
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18944\4192512858.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris_data, x='Species', y='SepalWidthCm' ,palette= ['blue','green','red'])

# %%
plt.figure(figsize=(8, 4))

sns.kdeplot(x='SepalWidthCm', data=iris_data, hue='Species', fill='True', palette= ['blue','green','red'])
plt.xlabel('SepalWidthCm')
plt.ylabel('Density')
plt.title('Density plot of SepalWidthCm')

plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.set_style=("white")

#create a boxplot plot
sns.boxplot(data=iris_data, x='Species', y='PetalLengthCm' ,palette= ['blue','green','red'])

plt.title('PetalLengthCm')
plt.xlabel('species')
plt.ylabel('Petal Length (cm)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18944\1910144825.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris_data, x='Species', y='PetalLengthCm' ,palette= ['blue','green','red'])

# %%
plt.figure(figsize=(8, 4))

sns.kdeplot(x='PetalLengthCm', data=iris_data, hue='Species', fill='True', palette= ['blue','green','red'])
plt.xlabel('PetalLengthCm')
plt.ylabel('Density')
plt.title('Density plot of PetalLengthCm')

plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.set_style=("white")

#create a boxplot plot
sns.boxplot(data=iris_data, x='Species', y='PetalWidthCm' ,palette= ['blue','green','red'])

plt.title('PetalWidthCm')
plt.xlabel('species')
plt.ylabel('PetalWidth(cm)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18944\3501363074.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris_data, x='Species', y='PetalWidthCm' ,palette= ['blue','green','red'])

# %%
plt.figure(figsize=(8, 4))

sns.kdeplot(x='PetalWidthCm', data=iris_data, hue='Species', fill='True', palette= ['blue','green','red'])
plt.xlabel('PetalWidthCm')
plt.ylabel('Density')
plt.title('Density plot of PetalWidthCm')

plt.show()

# %%
iris_data.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
species_colors= ['blue','green','red']

plt.pie(iris_data['Species'].value_counts(),labels=iris_data['Species'].unique(), colors=species_colors)

plt.title('Frequency Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.set_style=('white')
sns.scatterplot(data=iris_data,x='SepalLengthCm',y='SepalWidthCm',hue='Species')

plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.title('scatter plot of SepalWidthCm and SepalLengthCm')

plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.set_style=('white')
sns.scatterplot(data=iris_data,x='PetalLengthCm',y='PetalWidthCm',hue='Species')

plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.title('scatter plot of PetalLengthCm and PetalWidthCm')

plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.show()

# %%
X=iris_data.drop(['Id','Species'],axis=1)
y=iris_data['Species']

# %%
scale = StandardScaler()
X_scaled=scale.fit_transform(X)

X_scaled=pd.DataFrame(columns = X.columns, data=X_scaled)
X_scaled.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      -0.900681      1.032057      -1.341272     -1.312977
# 1      -1.143017     -0.124958      -1.341272     -1.312977
# 2      -1.385353      0.337848      -1.398138     -1.312977
# 3      -1.506521      0.106445      -1.284407     -1.312977
# 4      -1.021849      1.263460      -1.341272     -1.312977

# %%
y = y.map({'Iris-setosa' :0,
                         'Iris-versicolor' :1,
                         'Iris-virginica' :2})
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')

print('Decision Tree Classifier : ')
print('Accuracy:' ,round(accuracy,4))
print('precision:' ,round(precision,4))
print('Recall:' ,round(precision,4))
print('confusion matrix:')
print(confusion_matrix(y_test,y_pred))
# Out:
# Decision Tree Classifier :
# Accuracy: 1.0
# precision: 1.0
# Recall: 1.0
# confusion matrix:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
y_test.value_counts()
# Out:
# Species
# 2    11
# 0    10
# 1     9
# Name: count, dtype: int64

# %%
from sklearn import tree

plt.figure(figsize=(12, 8))
tree.plot_tree(dt, feature_names = X.columns, class_names = iris_data.Species.unique(), filled=True, fontsize =10)
plt.title('Decision tree for IRIS classification')
plt.show()
